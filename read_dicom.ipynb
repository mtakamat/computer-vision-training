# %%
import numpy as np
import pydicom as dicom
import os
import matplotlib.pyplot as plt

# %%
path="./"

# %%
d=dicom.read_file('./000015.dcm')
plt.imshow(d.pixel_array)

# %%
d
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.2.1125.1.7099949525090303582382425745023270
# (0008, 0020) Study Date                          DA: '20151124'
# (0008, 0030) Study Time                          TM: '165449.208569'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0064) Conversion Type                     CS: 'DV'
# (0008, 0070) Manufacturer                        LO: ''
# (0008, 0080) Institution Name                    LO: 'NIH'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'Pancreas'
# (0008, 103e) Series Description                  LO: 'Pancreas'
# ...
